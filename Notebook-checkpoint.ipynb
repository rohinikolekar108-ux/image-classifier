# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
train_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    r"C:\Users\Rohini\Desktop\Fruit_classifier\dataset\train",
    target_size=(64, 64),
    batch_size=32,
    class_mode="categorical"
)

test_data = test_gen.flow_from_directory(
    r"C:\Users\Rohini\Desktop\Fruit_classifier\dataset\test",
    target_size=(64, 64),
    batch_size=32,
    class_mode="categorical"
)
# Out:
# Found 800 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

model = Sequential([
    Input(shape=(64, 64, 3)),          # ✅ Input layer first
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')     # 5 classes
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    epochs=10,
    validation_data=test_data
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 892ms/step - accuracy: 0.4875 - loss: 1.3281 - val_accuracy: 0.6600 - val_loss: 0.9101
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.7188 - loss: 0.7562 - val_accuracy: 0.7550 - val_loss: 0.6767
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.8150 - loss: 0.5082 - val_accuracy: 0.7850 - val_loss: 0.5826
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8562 - loss: 0.4404 - val_accuracy: 0.7850 - val_loss: 0.4925
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8900 - loss: 0.3161 - val_accuracy: 0.8400 - val_loss: 0.4251
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9162 - loss: 0.2386 - val_accuracy: 0.8200 - val_loss: 0.6267
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9413 - loss: 0.2015 - val_accuracy: 0.8500 - val_loss: 0.5220
# Epoch 8/10
# ...

# %%
model.evaluate(test_data)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8800 - loss: 0.4544
# [0.4544254243373871, 0.8799999952316284]

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = r"C:\Users\Rohini\Desktop\Fruit_classifier\dataset\test\apple\apple1.jpg"

img = image.load_img(img_path, target_size=(64, 64))
img = image.img_to_array(img) / 255.0
img = np.expand_dims(img, axis=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 from tensorflow.keras.preprocessing import image
#       2 import numpy as np
# ----> 4 img = image.load_img("test_image.jpg", target_size=(64,64))
#       5 img = image.img_to_array(img) / 255.0
#       6 img = np.expand_dims(img, axis=0)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\image_utils.py:247, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     245     if isinstance(path, pathlib.Path):
#     246         path = str(path.resolve())
# --> 247     with open(path, "rb") as f:
#     248         img = pil_image.open(io.BytesIO(f.read()))
#     249 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_image.jpg'

# %%
model.save("fruit_classifier.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.save("fruit_classifier.h5")
#
# NameError: name 'model' is not defined
